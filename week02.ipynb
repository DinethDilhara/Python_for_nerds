# %% [markdown]
# ## <font color="red">Here we talk about</font>
#
# -  -> Functions
# -  -> Keyboard inputs
# -  -> Conversion functions
# -  -> Debugging
# -  -> Programming errors
# -  -> Python Exception Handling (Try and except)

# %% [markdown]
# **______________________________________________________________________________________**
#
# # <font color="green">**Functions**</font>
#
# **A function is a piece of code written to carry out a specified task.**
#
# Functions are case-sensitive
#
# There are 02 types of functions :
# -    -> <font color="blue">Built-in Functions</font>--> (functions that <u>given by python</u> ex: input(),print(),min())
# -    -> <font color="blue">User define Functions</font> --> (functions that are created by the user for specific tasks. use **def** for create it  )
#
# <u>Typical flow of a simple computer program</u>
#
# **input data** --> **process** --> **output data** /s.

# %%
#user defines a function to get a sum of two numbers
def sum (x,y):  
    result=x+y
    return result
x,y=[12,8]
total=sum (x,y)
print(total)
# Out:
# 20

# %% [markdown]
# **______________________________________________________________________________________**
#
# #  <font color="green">**Keyoard inputs**</font>
#
# - **input()**  function - program  stops and waits for the user input
# - using **str(),int(),float()** code can ask user for specific inputs

# %% [markdown]
# name = str(input("Enter your name :"))
# age = int(input("Enter your age :"))
# weight = float(input(" Enter your waeight :"))
# **______________________________________________________________________________________**

# %% [markdown]
# #  <font color="green">**Convertion function**</font>
#
# <u>int () function</u> takes any value and converts it to an integer and can convert floating-point values to integers, but it **doesn’t round off**
#
# <u>str () function</u> converts its argument to a string
#
# <u>float () function </u>converts integers and strings to floating-point numbers
#
# **______________________________________________________________________________________**

# %% [markdown]
# ![Python-Debugging-With-Pdb_Watermarked.ca76b26fbe1c.jpg](attachment:4def17a4-7050-4bb8-88b3-e6c077e39bf3.jpg)
#
# #  <font color="green"> **Debugging** </font>
#
# - <u>Bug</u> - An error in a program
# - <u>
# Debuggi</u>n  The Process of finding and correcting bugs
#
# Debugging can involve finding clues.
#
# - Error Messages: ->
# Understanding error messages is crucial for debugging
# - Using print for Debugging: ->
# Inserting extra print() statements in your code helps display variable values
# - Working Backwards from Errors:->
# Work backward from the error location to trace the flow of execution.
# .
# .
# execution.

# %% [markdown]
# **______________________________________________________________________________________**
#
# ## <font color="blue">**Exception Handling in Python**</font>
#
# if user inputs the wrong type of data? The ‘try/except’ construct can prevent the program crashing with an error
#
# Exception:  An error that occurs at <u>runtime.</u>  Handle an exception by wrapping the block of code in a **try . . . except construct.**

# %%
a = "1"
try:
    b = a + 2
except:
    print(a, " is not a number")
# Out:
# 1  is not a number

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %% [markdown]
# **______________________________________________________________________________________**
#
# #  <font color="green"> **Programming Errors** </font>
#
# Three types of errors in the program
#
# -     -> Syntax error
# -     -> Runtime error
# -     -> Semantic error
#
# ## <u>01.Syntax Error</u>
#
# These errors occur if typed code violates  the Python language rules
#
# ex: Missing parentheses, Incorrect indentation, Missing keywords
#
# -> Error message displayed when you try to run but it won't run

# %%
My_name = "dineth"
print My_name)
# Out:
#   Cell In[1], line 2
#     print My_name)
#                  ^
# SyntaxError: unmatched ')'

# %% [markdown]
# **------------------------------------------------------------------------------------------**
#
# ## <u>02. Runtime Error</u>
#
# These errors  appear when the **program has started running** also call as <u>exceptions</u>
#
# ex:  NameError , TypeError , ValueError , ZerodivisionError
#
# **------------------------------------------------------------------------------------------**
#
# ### <u>**NameError**</u>
#
# NameError:  means you have used a **variable before it has a value**

# %%
#NameError (here we have initialize num1 to num2 before num2 have defined)
num1=num2
num2=10
print(num1+num2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num1=num2
#       2 num2=10
#       3 print(num1+num2)
#
# NameError: name 'num2' is not defined

# %%
#Exception for NameError
try:
    num1=num2
    num2=10
    print(num1+num2)
except NameError:
    print("Name Error")
# Out:
# Name Error

# %% [markdown]
# **------------------------------------------------------------------------------------------**
#
# ### <u>**TypeError**</u>
#
# **TypeErro**r: often when an expression tries to combine two types that are not compatible
#
# <u>e.g., integer and string </u>
#
# Can use **type()** to check what type of variable is

# %%
#TypeError and check data type
name = "dineth"
age = 10
print(type(name))
print(type(age))
print(name + age )
# Out:
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 print(type(name))
#       4 print(type(age))
# ----> 5 print(name + age )
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Exception for TypeError
try:
    name = "dineth"
    age = 10
    print(name + age )
except:
    print("TypeError" )

# %% [markdown]
# **------------------------------------------------------------------------------------------**
# ### <u>**ValueError**</u>
#
# ValueError: when an operation or function receives an argument that has the **right type but an inappropriate value**
#
# ex: ask  the user for a number and instead they enter a character t
#
# can use **data conversion** str(),int() etc.. or **try exception** to fix ValueError

# %%
#valueerror in here abc is to int() 
name = int("dilhara")
print(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 #valueerror in here abc is to int()
# ----> 2 name = int("dilhara")
#       3 print(name)
#
# ValueError: invalid literal for int() with base 10: 'dilhara'

# %%
#Exception for ValueError
try:
    name = int("dilhara")
    print(name)
except:
    print("value Error")
# Out:
# value Error

# %% [markdown]
# **------------------------------------------------------------------------------------------**
# ### <u>**ZeroDivisionError**</u>
#
#  **ZeroDivisionE**rror**: with Python it is not possible to divide numbers by zero.
#
#  •	If you attempt to divide by 0, python will throw a ZeroDivisionError
#
#  To fix this add **"if" statement to ignore if value is zero** or **try except**

# %%
a = 0
b =100
c = b/a
d = a/b
print(c,d)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 a = 0
#       2 b =100
# ----> 3 c = b/a
#       4 d = a/b
#       5 print(c,d)
#
# ZeroDivisionError: division by zero

# %%
#Exception for ZeroDivisionError
try:
    a = 0
    b =100
    c = b/a
    d = a/b
    print(c,d)
except ZeroDivisionError:
    print("ZeroDivision Error")
# Out:
# zerodivision error

# %% [markdown]
# **______________________________________________________________________________________**
#
# ## <u>03. Semantic Error</u>
#
# **Semantic error** - An error in a program that makes it do something other than what the programmer intended
#
# It's like code is running but it **doesn't produce the expected answer.**
#
# These kinds of errors are known as **logical errors** too.
#
# ex: Incorrect Algorithm, Wrong Conition, wrong Logic
#
# **______________________________________________________________________________________**
